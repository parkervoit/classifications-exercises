# %%
from env import host, username, password
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import acquire as ac
import prepare

# %%
df = ac.get_titanic_data()
df
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# 0          S   Third  None  Southampton      0
# 1          C   First     C    Cherbourg      0
# 2          S   Third  None  Southampton      1
# 3          S   First     C  Southampton      0
# 4          S   Third  None  Southampton      1
# ..       ...     ...   ...          ...    ...
# 886        S  Second  None  Southampton      1
# 887        S   First     B  Southampton      1
# 888        S   Third  None  Southampton      0
# 889        C   First     C    Cherbourg      1
# 890        Q   Third  None   Queenstown      1
#
# [891 rows x 13 columns]

# %%
prepare.impute_mode()

# %%
def prep_titanic_data(df):
    '''
    takes in a dataframe of the titanic dataset as it is acquired and returns a cleaned dataframe
    arguments: df: a pandas DataFrame with the expected feature names and columns
    return: train, test, split: three dataframes with the cleaning operations performed on them
    '''
    df = df.drop_duplicates()
    df = df.drop(columns=['deck', 'embarked', 'class', 'age', 'passenger_id'])
    train, test = train_test_split(df, test_size=0.2, random_state=1349, stratify=df.survived)
    train, validate = train_test_split(train, train_size=0.7, random_state=1349, stratify=train.survived)
    train, validate, test = impute_mode(train, validate, test)
    train = pd.get_dummies(data = train, columns = ['sex', 'embark_town'], drop_first=[True,True])
    validate = pd.get_dummies(data = validate, columns = ['sex', 'embark_town'], drop_first=[True,True])
    test = pd.get_dummies(data = test, columns = ['sex', 'embark_town'], drop_first=[True,True])
    return train, validate, test

# %%
train, validate, test = prep_titanic_data(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ac6e73ab76ac> in <module>
# ----> 1 train, validate, test = prep_titanic_data(df)
#
# <ipython-input-3-c74868fd3578> in prep_titanic_data(df)
#       9     train, test = train_test_split(df, test_size=0.2, random_state=1349, stratify=df.survived)
#      10     train, validate = train_test_split(train, train_size=0.7, random_state=1349, stratify=train.survived)
# ---> 11     train, validate, test = impute_mode(train, validate, test)
#      12     train = pd.get_dummies(data = train, columns = ['sex', 'embark_town'], drop_first=[True,True])
#      13     validate = pd.get_dummies(data = validate, columns = ['sex', 'embark_town'], drop_first=[True,True])
#
# NameError: name 'impute_mode' is not defined

# %%
train
# Out:
#      survived  pclass  sibsp  parch     fare  alone  sex_male  \
# 474         0       3      0      0   9.8375      1         0
# 370         1       1      1      0  55.4417      0         1
# 573         1       3      0      0   7.7500      1         0
# 110         0       1      0      0  52.0000      1         1
# 167         0       3      1      4  27.9000      0         0
# ..        ...     ...    ...    ...      ...    ...       ...
# 735         0       3      0      0  16.1000      1         1
# 163         0       3      0      0   8.6625      1         1
# 770         0       3      0      0   9.5000      1         1
# 196         0       3      0      0   7.7500      1         1
# 94          0       3      0      0   7.2500      1         1
#
#      embark_town_Queenstown  embark_town_Southampton
# 474                       0                        1
# 370                       0                        0
# 573                       1                        0
# 110                       0                        1
# 167                       0                        1
# ..                      ...                      ...
# 735                       0                        1
# 163                       0                        1
# 770                       0                        1
# 196                       1                        0
# 94                        0                        1
#
# [498 rows x 9 columns]

# %%
validate
# Out:
#      survived  pclass  sibsp  parch      fare  alone  sex_male  \
# 569         1       3      0      0    7.8542      1         1
# 532         0       3      1      1    7.2292      0         1
# 223         0       3      0      0    7.8958      1         1
# 35          0       1      1      0   52.0000      0         1
# 93          0       3      1      2   20.5750      0         1
# ..        ...     ...    ...    ...       ...    ...       ...
# 91          0       3      0      0    7.8542      1         1
# 258         1       1      0      0  512.3292      1         0
# 186         1       3      1      0   15.5000      0         0
# 108         0       3      0      0    7.8958      1         1
# 845         0       3      0      0    7.5500      1         1
#
#      embark_town_Queenstown  embark_town_Southampton
# 569                       0                        1
# 532                       0                        0
# 223                       0                        1
# 35                        0                        1
# 93                        0                        1
# ..                      ...                      ...
# 91                        0                        1
# 258                       0                        0
# 186                       1                        0
# 108                       0                        1
# 845                       0                        1
#
# [214 rows x 9 columns]

# %%
test
# Out:
#      survived  pclass  sibsp  parch     fare  alone  sex_male  \
# 691         1       3      0      1  13.4167      0         0
# 762         1       3      0      0   7.2292      1         1
# 869         1       3      1      1  11.1333      0         1
# 174         0       1      0      0  30.6958      1         1
# 45          0       3      0      0   8.0500      1         1
# ..        ...     ...    ...    ...      ...    ...       ...
# 871         1       1      1      1  52.5542      0         0
# 221         0       2      0      0  13.0000      1         1
# 134         0       2      0      0  13.0000      1         1
# 262         0       1      1      1  79.6500      0         1
# 799         0       3      1      1  24.1500      0         0
#
#      embark_town_Queenstown  embark_town_Southampton
# 691                       0                        0
# 762                       0                        0
# 869                       0                        1
# 174                       0                        0
# 45                        0                        1
# ..                      ...                      ...
# 871                       0                        1
# 221                       0                        1
# 134                       0                        1
# 262                       0                        1
# 799                       0                        1
#
# [179 rows x 9 columns]

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = analysis.model_variables(['pclass','sex_male','alone'], 'survived')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-02ae6a685c3d> in <module>
# ----> 1 X_train, y_train, X_validate, y_validate, X_test, y_test = analysis.model_variables(['pclass','sex_male','alone'], 'survived')
#
# ~/Desktop/codeup-data-science/classifications-exercises/analysis.py in model_variables(X_cols, y_col)
#      19     return train, validate, test
#      20
# ---> 21 def model_variables(X_cols, y_col):
#      22     X_train, y_train = train[X_cols], train[y_col]
#      23     X_validate, y_validate = validate[X_cols], validate[y_col]
#
# NameError: name 'train' is not defined

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-931765772341> in <module>
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined
